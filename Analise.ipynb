# %%
import pandas as pd

# %%
piso = pd.read_csv('concorrencia.csv')
construcao = pd.read_csv('concorrencia0construcao.csv')

# %%
piso['Avaliação'] = piso['Avaliação'].str.strip('()')
construcao['Avaliação'] = construcao['Avaliação'].str.strip('()')

# %%
piso['Avaliação'] = piso['Avaliação'].astype(float)
construcao['Avaliação'] = construcao['Avaliação'].astype(float)

# %%
#piso.sort_values('Avaliação', ascending=False)[['Nome','Avaliação']]
construcao.sort_values('Avaliação', ascending=False)[['Nome','Avaliação']]
# Out:
#                                                   Nome  Avaliação
# 109                                  Telhanorte Catuaí      989.0
# 19                               Telhanorte Tiradentes      847.0
# 12                                              Todimo      725.0
# 6                                Leroy Merlin Londrina      410.0
# 2                                  Depósito São Marcos      317.0
# 191                   Macripar Parafusos & Ferramentas      299.0
# 133                                    DEPÓSITO ROMANI      280.0
# 90                                     DEPÓSITO ROMANI      280.0
# 7                                               Todimo      274.0
# 66         Depósito Roseira - Construção e Acabamentos      235.0
# 22         Depósito Roseira - Construção e Acabamentos      235.0
# 110        Depósito Roseira - Construção e Acabamentos      235.0
# 73         Depósito Roseira - Construção e Acabamentos      235.0
# ...

# %%
piso[piso['Nome'].str.contains("Pisos")]['Nome']
# Out:
# 0                                Pisos Londrina - Paver
# 1                                          London Pisos
# 2                                       Pisos Passarela
# 3             PisoFácil (Store) (Pisos e Revestimentos)
# 5     HOUSE Pisos Porcelanato e Acabamentos londrina...
# 6                                              LG Pisos
# 8                           Casalon Pisos e acabamentos
# 9               Decorando Pisos Laminados e Acabamentos
# 12                                          Globo Pisos
# 14                             Pisos Laminados Londrina
# 16       Projeto Natural-Pisos e Acabamentos em Madeira
# 17                           Europiso Com de Pisos Indl
# 29    Grupo Xara (Decoração - Acabamentos - Pisos - ...
# 31           Aqui K J R Pisos e Materiais de Construção
# 35                          Justo Pisos e Revestimentos
# 49               Europiso Comércio de Pisos Industriais
# 52    Clicpiso Pisos Laminados, Persianas, Portas pr...
# ...
